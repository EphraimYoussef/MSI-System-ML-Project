# %%
import cv2
import numpy as np
import os
import random

# %% [markdown]
# ## Global Parameters

# %%
IMAGE_EXTENSIONS = (".jpg", ".png", ".jpeg")
ROTATION_RANGE = (-10, 10)
BRIGHTNESS_RANGE = (-15, 15)
CONTRAST_RANGE = (0.9, 1.1)
NOISE_STD_RANGE = (2, 6)
ZOOM_RANGE = (0.9, 1.0)

# %% [markdown]
# ## Dataset Paths

# %%
INPUT_PATH = "../data_split/train"
OUTPUT_PATH = "../data_split/train_aug"
os.makedirs(OUTPUT_PATH, exist_ok=True)

# %% [markdown]
# ## Image Augmentation Functions

# %%
def random_augment(img):
    h, w = img.shape[:2]

    angle = random.uniform(*ROTATION_RANGE)
    M = cv2.getRotationMatrix2D((w//2, h//2), angle, 1)
    img = cv2.warpAffine(img, M, (w, h), borderMode=cv2.BORDER_REFLECT)

    if random.random() < 0.5:
        img = cv2.flip(img, 1)

    alpha = random.uniform(*CONTRAST_RANGE)
    beta = random.randint(*BRIGHTNESS_RANGE)
    img = cv2.convertScaleAbs(img, alpha=alpha, beta=beta)

    noise_std = random.uniform(*NOISE_STD_RANGE)
    noise = np.random.normal(0, noise_std, img.shape)
    img = np.clip(img + noise, 0, 255).astype(np.uint8)

    zoom = random.uniform(*ZOOM_RANGE)
    nh, nw = int(h * zoom), int(w * zoom)
    y1 = (h - nh) // 2
    x1 = (w - nw) // 2
    img = img[y1:y1+nh, x1:x1+nw]
    img = cv2.resize(img, (w, h))

    return img

# %%
def count_images(path):
    return {
        cls: len([
            f for f in os.listdir(os.path.join(path, cls))
            if f.lower().endswith(IMAGE_EXTENSIONS)
        ])
        for cls in os.listdir(path)
        if os.path.isdir(os.path.join(path, cls))
    }

# %%
counts = count_images(INPUT_PATH)

before_total = sum(counts.values())
num_classes = len(counts)

target_total = int(before_total * 1.5)
target_per_class = target_total // num_classes

print("Target total images:", target_total)
print("Target per class:", target_per_class)

cnt = 0
for cls, count in counts.items():
    in_cls = os.path.join(INPUT_PATH, cls)
    out_cls = os.path.join(OUTPUT_PATH, cls)
    os.makedirs(out_cls, exist_ok=True)

    images = [
        f for f in os.listdir(in_cls)
        if f.lower().endswith(IMAGE_EXTENSIONS)
    ]

    # Copy originals safely
    for img_name in images:
        img_path = os.path.join(in_cls, img_name)
        img = cv2.imread(img_path)

        if img is None:
            print(f"[SKIP] Cannot read {img_path}")
            cnt += 1
            continue

        cv2.imwrite(os.path.join(out_cls, img_name), img)

    current = count
    idx = 0

    while current < target_per_class:
        img_name = random.choice(images)
        img_path = os.path.join(in_cls, img_name)
        img = cv2.imread(img_path)

        if img is None:
            continue

        aug = random_augment(img)

        cv2.imwrite(
            os.path.join(out_cls, f"{os.path.splitext(img_name)[0]}_aug{idx}.jpg"),
            aug
        )

        current += 1
        idx += 1

print("Train augmentation completed")
print("Skipped images:", cnt)
# Out:
# Target total images: 2055
# Target per class: 342
# [SKIP] Cannot read ../data_split/train\cardboard\2ec9d19b-8027-4c77-a13f-5eee033b9868.jpg
# [SKIP] Cannot read ../data_split/train\cardboard\31381a44-38d6-4a44-9384-7690727801bc.jpg
# [SKIP] Cannot read ../data_split/train\cardboard\345bdb67-4190-4235-a16f-b60c1556a28d.jpg
# [SKIP] Cannot read ../data_split/train\cardboard\4840d678-7af4-4a2d-bda1-338c2f2a59c5.jpg
# [SKIP] Cannot read ../data_split/train\cardboard\509251d8-4e3a-4f1e-aabc-4d034b0f2455.jpg
# [SKIP] Cannot read ../data_split/train\cardboard\5b7da318-c2ab-4c29-8ace-19895a890840.jpg
# [SKIP] Cannot read ../data_split/train\cardboard\8617221e-dc90-48fe-a116-46350b5f814e.jpg
# [SKIP] Cannot read ../data_split/train\cardboard\88ce5fbf-e9c7-40ad-87a6-deffe95d8ee8.jpg
# [SKIP] Cannot read ../data_split/train\cardboard\bff223bf-1a84-4d38-a486-c3f4c9bfef5e.jpg
# [SKIP] Cannot read ../data_split/train\cardboard\d5856b01-c157-4e34-b921-80f29252976a.jpg
# [SKIP] Cannot read ../data_split/train\glass\14bbfb58-f21f-41ae-9b48-d7d10b41d10e.jpg
# [SKIP] Cannot read ../data_split/train\glass\14f50b32-f879-4c07-ba05-54bf3c6a8693.jpg
# [SKIP] Cannot read ../data_split/train\glass\2a3677eb-7c7a-4dea-9157-23c55252d855.jpg
# [SKIP] Cannot read ../data_split/train\glass\393f6b9f-f426-4858-9766-7ba12ed51df3.jpg
# [SKIP] Cannot read ../data_split/train\glass\72792053-5f1a-457c-a0da-e5200aadbe1d.jpg
# [SKIP] Cannot read ../data_split/train\glass\90cd02d9-1c1a-4cf4-a08f-100f62bf7968.jpg
# [SKIP] Cannot read ../data_split/train\glass\b9304563-57f2-4f71-9f19-d845969f7fbb.jpg
# [SKIP] Cannot read ../data_split/train\glass\b9ab8ae2-90ee-4cda-8423-3b564669d283.jpg
# [SKIP] Cannot read ../data_split/train\glass\df3b36b0-1e25-4901-a449-a4a3a2c59582.jpg
# [SKIP] Cannot read ../data_split/train\glass\e7fd346b-295d-4218-b975-7f25f1c56e24.jpg
# [SKIP] Cannot read ../data_split/train\metal\07961e53-3d89-43a2-aafc-d50743ad0490.jpg
# [SKIP] Cannot read ../data_split/train\metal\0aac82c1-8daf-421b-b4b7-e24b79e5a09d.jpg
# [SKIP] Cannot read ../data_split/train\metal\19861069-7ec9-4b61-92cf-fded78a27ab5.jpg
# [SKIP] Cannot read ../data_split/train\metal\2bc2cc80-5175-4dca-9a8c-c4a43693228c.jpg
# [SKIP] Cannot read ../data_split/train\metal\5eb088b0-521e-45c4-b4a1-70811173a7c1.jpg
# [SKIP] Cannot read ../data_split/train\metal\6fb8502a-b6ad-4044-8419-d8dbcf423218.jpg
# [SKIP] Cannot read ../data_split/train\metal\a67f3a69-1392-4a06-abd4-be9ea055465c.jpg
# [SKIP] Cannot read ../data_split/train\metal\d11915ba-4e61-463f-9359-290a6819cf80.jpg
# [SKIP] Cannot read ../data_split/train\metal\d406f18e-ce22-4720-95ae-d52302664b4f.jpg
# [SKIP] Cannot read ../data_split/train\paper\08567821-39e1-401b-bdb4-2f636883d624.jpg
# [SKIP] Cannot read ../data_split/train\paper\0c33b602-b360-489f-9ed6-6f748f834cb4.jpg
# [SKIP] Cannot read ../data_split/train\paper\122d1fdd-5d5b-4b25-a7cd-a7fb688cb448.jpg
# [SKIP] Cannot read ../data_split/train\paper\1c5812c2-54f9-4e40-88f8-17ceef651454.jpg
# [SKIP] Cannot read ../data_split/train\paper\1f1f1143-61aa-45c4-b6b2-1908d5ea9c34.jpg
# [SKIP] Cannot read ../data_split/train\paper\29e3d437-2f89-4a83-b431-d0e24187d500.jpg
# [SKIP] Cannot read ../data_split/train\paper\2fea66f0-97bd-44f2-813b-5fb10a360900.jpg
# [SKIP] Cannot read ../data_split/train\paper\3b5bb1a4-7819-4167-a610-5e35c6f4b074.jpg
# [SKIP] Cannot read ../data_split/train\paper\3ca1f3fb-0327-4e8b-86c1-20d9f40b35d4.jpg
# [SKIP] Cannot read ../data_split/train\paper\405d964f-7459-45d9-9536-203242145351.jpg
# [SKIP] Cannot read ../data_split/train\paper\47b3d05f-860e-43dc-87ff-8cd4b17edb34.jpg
# [SKIP] Cannot read ../data_split/train\paper\4b5f4164-7e00-473e-8bc9-60b8f76eae30.jpg
# [SKIP] Cannot read ../data_split/train\paper\5a27908f-fb31-4c3f-bad5-4cf290cb9809.jpg
# [SKIP] Cannot read ../data_split/train\paper\6f5555ff-2f58-4fc6-8a55-a55cf0d5aeb4.jpg
# [SKIP] Cannot read ../data_split/train\paper\abc3c1a5-cf89-4492-90d9-d065b16d5ad9.jpg
# [SKIP] Cannot read ../data_split/train\paper\ad28f223-7e3c-486b-9c29-19fc9ab3b0eb.jpg
# [SKIP] Cannot read ../data_split/train\paper\b9eb5626-98cf-42e8-a2f6-d395f3c6528f.jpg
# [SKIP] Cannot read ../data_split/train\paper\c0aff1d1-73c2-4141-b647-08307742df4b.jpg
# [SKIP] Cannot read ../data_split/train\paper\d4ac11b1-3cd0-4d3e-9e36-a9f537bde05c.jpg
# [SKIP] Cannot read ../data_split/train\paper\e7e7ee96-4aed-448e-beb6-22a40e70a780.jpg
# [SKIP] Cannot read ../data_split/train\paper\e9ddd8f5-85d6-45e0-b607-104259ca6fbb.jpg
# [SKIP] Cannot read ../data_split/train\plastic\09b5dda8-5e1d-4a28-9368-0e72ee0739cb.jpg
# [SKIP] Cannot read ../data_split/train\plastic\1c3fe472-7dce-4b3d-be3a-eeb998fe951e.jpg
# [SKIP] Cannot read ../data_split/train\plastic\1d4df275-6e8e-4b8d-8779-6813c6ea7948.jpg
# [SKIP] Cannot read ../data_split/train\plastic\1db23e25-cbdf-4b5d-925a-9b4f5d600d04.jpg
# [SKIP] Cannot read ../data_split/train\plastic\381aeb1b-4efb-4314-8ca8-16c3a981a1f3.jpg
# [SKIP] Cannot read ../data_split/train\plastic\475dbb63-d767-4f9c-874a-7b133e2aa099.jpg
# [SKIP] Cannot read ../data_split/train\plastic\73155f34-0d5e-4c69-9396-b4cc76e32863.jpg
# [SKIP] Cannot read ../data_split/train\plastic\7c35a035-5207-4406-8cf2-0b4ce836d08c.jpg
# [SKIP] Cannot read ../data_split/train\plastic\7cc4bc86-2e00-495e-be08-86d998ac5077.jpg
# [SKIP] Cannot read ../data_split/train\plastic\8a2c0933-7195-4e23-9e56-8382db86461c.jpg
# [SKIP] Cannot read ../data_split/train\plastic\99733095-4545-46f7-b223-ee30c3c3bb99.jpg
# [SKIP] Cannot read ../data_split/train\plastic\9cc966b8-287a-4922-bcd6-b43721ae1db5.jpg
# [SKIP] Cannot read ../data_split/train\plastic\b7584c85-26bf-4a4c-a2f5-1c353154cce5.jpg
# [SKIP] Cannot read ../data_split/train\plastic\baa91f90-1fb6-4dd6-a274-69e20e658b0e.jpg
# [SKIP] Cannot read ../data_split/train\plastic\ce89dde5-22ae-4a76-8cea-875f87dd3e56.jpg
# [SKIP] Cannot read ../data_split/train\plastic\d3c94e8a-f195-473d-b541-9ffa0501a6e7.jpg
# [SKIP] Cannot read ../data_split/train\plastic\dec17c1e-57a9-4746-8ee2-2a9314664654.jpg
# [SKIP] Cannot read ../data_split/train\plastic\e5147630-f309-452f-90e7-aeb43878102e.jpg
# [SKIP] Cannot read ../data_split/train\plastic\fd28a009-65e2-4d2b-bc94-6d054ef36734.jpg
# [SKIP] Cannot read ../data_split/train\trash\0e375c5f-34a7-481d-8c55-e5fdaa75f836.jpg
# [SKIP] Cannot read ../data_split/train\trash\93380387-da03-44af-9e4b-32c0beece110.jpg
# [SKIP] Cannot read ../data_split/train\trash\a31e2570-f309-4e40-95bc-57ee2dfdf412.jpg
# Train augmentation completed
# Skipped images: 72

# %%
def count_images_per_class(dataset_path):
    counts = {}
    total = 0

    for cls in sorted(os.listdir(dataset_path)):
        cls_path = os.path.join(dataset_path, cls)
        if not os.path.isdir(cls_path):
            continue

        num_images = len([
            f for f in os.listdir(cls_path)
            if f.lower().endswith(IMAGE_EXTENSIONS)
        ])

        counts[cls] = num_images
        total += num_images

    return counts, total

# %%
print("\nClass distribution after augmentation:")
for cls in os.listdir(OUTPUT_PATH):
    cls_path = os.path.join(OUTPUT_PATH, cls)
    if os.path.isdir(cls_path):
        count = len([f for f in os.listdir(cls_path)
                    if f.lower().endswith(IMAGE_EXTENSIONS)])
        print(f"   {cls}: {count} images")
# Out:
# Class distribution after augmentation:
#    cardboard: 332 images
#    glass: 332 images
#    metal: 333 images
#    paper: 321 images
#    plastic: 323 images
#    trash: 339 images

# %%
before_counts, before_total = count_images_per_class(INPUT_PATH)

print("Images BEFORE augmentation:")

for cls, cnt in before_counts.items():
    print("="*40)
    print(f"{cls:10s}: {cnt}")
    print(f"Percentage of {cls:10s}: {cnt / before_total * 100:.2f}%")
    print(f"count after 50% augmentation --> {int(cnt * 1.5)}")
print("TOTAL:", before_total)
print ("After 50 % augmentation --> ", before_total * 1.5)
# Out:
# Images BEFORE augmentation:
# ========================================
# cardboard : 181
# Percentage of cardboard : 13.21%
# count after 50% augmentation --> 271
# ========================================
# glass     : 280
# Percentage of glass     : 20.44%
# count after 50% augmentation --> 420
# ========================================
# metal     : 229
# Percentage of metal     : 16.72%
# count after 50% augmentation --> 343
# ========================================
# paper     : 333
# Percentage of paper     : 24.31%
# count after 50% augmentation --> 499
# ========================================
# plastic   : 270
# Percentage of plastic   : 19.71%
# count after 50% augmentation --> 405
# ========================================
# trash     : 77
# Percentage of trash     : 5.62%
# count after 50% augmentation --> 115
# TOTAL: 1370
# After 50 % augmentation -->  2055.0

# %%
after_counts, after_total = count_images_per_class(OUTPUT_PATH)

print("\nImages AFTER augmentation:")
for cls, cnt in after_counts.items():
    print(f"{cls:10s}: {cnt}")
print("TOTAL:", after_total)
# Out:
# Images AFTER augmentation:
# cardboard : 332
# glass     : 332
# metal     : 333
# paper     : 321
# plastic   : 323
# trash     : 339
# TOTAL: 1980

# %%
print("Augmentation ratio ", (after_total - before_total) / before_total * 100)
# Out:
# Augmentation ratio  44.52554744525548
